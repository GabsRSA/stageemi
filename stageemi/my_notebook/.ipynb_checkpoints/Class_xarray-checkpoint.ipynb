# %%
from xarray_map import interactive_map

# %%
m = interactive_map()
# Out:
# <xarray.DataArray 'mask' (id: 8, latitude: 119, longitude: 161)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        ...,
#
# ...

# %%
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9a40b379906c> in <module>
# ----> 1 m
#
# NameError: name 'm' is not defined

# %%
import numpy as np

# %%
bins=np.linspace(-.5,1,200)
bins
# Out:
# array([-0.5       , -0.49246231, -0.48492462, -0.47738693, -0.46984925,
#        -0.46231156, -0.45477387, -0.44723618, -0.43969849, -0.4321608 ,
#        -0.42462312, -0.41708543, -0.40954774, -0.40201005, -0.39447236,
#        -0.38693467, -0.37939698, -0.3718593 , -0.36432161, -0.35678392,
#        -0.34924623, -0.34170854, -0.33417085, -0.32663317, -0.31909548,
#        -0.31155779, -0.3040201 , -0.29648241, -0.28894472, -0.28140704,
#        -0.27386935, -0.26633166, -0.25879397, -0.25125628, -0.24371859,
#        -0.2361809 , -0.22864322, -0.22110553, -0.21356784, -0.20603015,
#        -0.19849246, -0.19095477, -0.18341709, -0.1758794 , -0.16834171,
#        -0.16080402, -0.15326633, -0.14572864, -0.13819095, -0.13065327,
#        -0.12311558, -0.11557789, -0.1080402 , -0.10050251, -0.09296482,
#        -0.08542714, -0.07788945, -0.07035176, -0.06281407, -0.05527638,
#        -0.04773869, -0.04020101, -0.03266332, -0.02512563, -0.01758794,
# ...

# %%
np.diff(bins)
# Out:
# array([0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
#        0.00753769, 0.00753769, 0.00753769, 0.00753769, 0.00753769,
# ...

# %%
import json
zsympo = "../GeoData/ZonesSympo/zones_sympo_4326.json"
with open(zsympo) as geojson1:
    poly_geojson = json.load(geojson1)

# %%
poly_geojson
# Out:
# {'type': 'FeatureCollection',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'id': '661', 'name': 'Cap Bear (large)'},
#    'id': '661',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[3.138645924086014, 42.58870466219895],
#       [3.2821251682121, 42.44385474922017],
#       [3.2821251682121, 42.44385474922017],
#       [3.598036163086266, 42.47648904999271],
#       [3.479934646166222, 42.639469773566866],
#       [3.479934646166222, 42.639469773566866],
#       [3.138645924086014, 42.58870466219895]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '662', 'name': 'Argeles-Leucate (large)'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[3.479934646166222, 42.639469773566866],
#       [3.138645924086014, 42.58870466219895],
#       [3.138645924086014, 42.58870466219895],
#       [3.142130580147128, 42.84015177744743],
# ...
