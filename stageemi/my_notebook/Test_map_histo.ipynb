# %%
from xarray_map import interactive_choro_map

# %%
interactive_choro_map()
# Out:
# interactive_choro_map(children=(Map(center=[45, 0], controls=(ZoomControl(options=['position', 'zoom_in_text',…
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/anaconda3/envs/cartopy/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# /opt/anaconda3/envs/cartopy/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
# ...
